# %% [markdown]
# #Modelling geospatial weather data using MapReduce
# **by Helge Munk Jacobsen.**
#
# This notebook deals with various common tasks when dealing with large amounts of geospatial data. The few subjects that we will touch upon include, MapReduce (using the MRjob package), R-trees, principal component analysis (PCA), minimum description length (MDL).
#
# The notebook was created as part of a homework assignment for course 291 Big Data Analysis with Professor Yoav Freund at UC San Diego.
#
# ---

# %% [markdown]
# #### Objective
# We want to model the maximum and minimum temperature around the world using principal component analysis (PCA). But since not all places on earth behave the same way, we want to fit PCAs to several different areas in order to get a better fit. This raises the following problems:
# * **How do we avoid partitioning the data uneven, so that some areas will overfit and others will get to simple a model?**
# * **How do we make a good partitioning of the data into areas that meteorologically behave the same way?**
#
# #### Approach
# 1. [Aggregation - MapReduce][measurement_count]<br />Find the distrubution of measurements by counting the number of measurements for each weather station using _MapReduce_ (the approximatly 9 million years of measurements are aggregated into counts for each for the around 85000 weather stations).
# 2. [Partition - R-tree][rtree]<br />Partition the data into areas of approximately equal number of measurements using an _R-tree_ (resulting in areas of uneven size).
# 3. [Initial model - PCA][pca]<br />Fit models on each area using _principal component analysis (PCA)_.
# 4. [Merge models - MDL][mdl]<br />Merge areas with similar meteorologically behaviour together using the concept of _minimum description lenth (MDL)_.
#
# [measurement_count]: #Settings
# [rtree]: #Settings
# [pca]: #Settings
# [mdl]: #Settings

# %% [markdown]
# ## Settings

# %% [markdown]
# To get every thing ready for the analysis we need a little initial administration..

# %% [markdown]
# ##### Getting ready for doing map-reduce jobs on the server provided på Professor Yoav Freund:

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

import pickle

# %%
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print 'ID: %s, key_id: %s' % (ID, key_id)
# Out:
# ID: , key_id: AKIAI2CZWQBAJJU3WUEA

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x3728b10> no_script.yoavfreund.20140517.080731.371759 j-2EFV3O64LF1U2 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3ca7850> no_script.yoavfreund.20140525.194233.003342 j-2KCJE554SGITB WAITING
# u'j-2KCJE554SGITB'

# %% [markdown]
# ##### Loading in the station data

# %% [markdown]
# The sation data contain information about position, name and elevation og the station.

# %%
import gzip
import pickle
import pandas as pd

stations_file = '/home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce/HW2/stations.pkl.gz'
stations = pickle.load(gzip.open(stations_file,'rb'))
stations.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID
# ACW00011604     NaN     NaN    NaN
# ACW00011647     NaN     NaN    NaN
# AE000041196     GSN     NaN  41196
# AF000040930     GSN     NaN  40930
# AG000060390     GSN     NaN  60390
#
# [5 rows x 8 columns]

# %%
print "Number of stations:", stations.shape[0]
# Out:
# Number of stations: 85284

# %% [markdown]
# We will use a small sample of the weather data to show how what it happening to the data:

# %%
local_weather_data = '/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !head -3 $local_weather_data
# Out:
# ASN00054128,DAPR,1969,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,2,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ASN00054128,DAPR,1971,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,3,,,,,,,3,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ...

# %% [markdown]
# Okay, now we are ready...

# %% [markdown]
# ## 1 ) Aggregation: Finding the distribution of measurements using MapReduce

# %% [markdown]
# Lets first decide on which type of measurement we are interested in.
#
# The most common are:
# * 'PRCP' = Precipitation (tenths of mm)
# * 'SNOW' = Snowfall (mm)
# * 'SNWD' = Snow depth (mm)
# * 'TMAX' = Maximum temperature (tenths of degrees C)
# * 'TMIN' = Minimum temperature (tenths of degrees C)
#
# But there are many more to choose between: https://github.com/yoavfreund/UCSD_BigData/blob/15bc481d8bde88482cc1260eb90915409415f13c/data/weather/ghcnd-readme.txt

# %%
MEASUREMENT_TYPE = 'PRCP'

# %% [markdown]
# Lets first see what the data looks like. Her are the first 3 rows:

# %%
# !head -3 $local_weather_data
# Out:
# ASN00054128,DAPR,1969,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,2,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ASN00054128,DAPR,1971,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,3,,,,,,,3,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ...

# %% [markdown]
# In order to count the measurements for each station in the map-reduce framework we need (for each line):
#
# **Mapper:**
# The key will be the station ID and the value is the total number of measurements. We only emit a key-value pair if the measurement type is the type of interest. We could also emit a key-value pair for each single measurement, but this would cause extra work for the reducers.
#
# **Reducer:**
# Aggregate all measurement counts.
#
# **Combiner**
# We don't need a combiner, but if a mapper encounters multiple lines with same station (this happens since each year gets it own line) we could add a combiner that sums all the measurement counts before sending the data to the reducers.

# %%
# %%writefile count_measurements.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class count_measurements(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = elements[2]
            measurements = elements[3:]
            no_of_measurements = sum([1 for m in measurements if m != ""])
            
            # Emit the key-value pair
            if measure_type == 'PRCP' and station != 'station': #filter out the unwanted measurements and the header line
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, no_of_measurements)
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, word, counts):
        try:
            if word[0] == 'error':
                yield(key,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            yield (word, sum(counts))
        except Exception, e:
            yield (('error','reducer', str(e)), 1)
        
    def combiner(self, word, counts):
        try:
            self.increment_counter('MrJob Counters','combiner',1)
            yield (word, sum(counts))
        except Exception, e:
            yield (('error','combiner', str(e)), 1)
        
if __name__ == '__main__':
    count_measurements.run()
# Out:
# Overwriting count_measurements.py

# %%
# %%writefile count_TMIN_TMAX.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class count_TMIN_TMAX(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = elements[2]
            measurements = elements[3:]
            no_of_measurements = sum([1 for m in measurements if m != ""])
            
            # Emit the key-value pair
            if (measure_type == 'TMIN' or measure_type == 'TMAX') and station != 'station': #filter out the unwanted measurements and the header line
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, no_of_measurements)
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            yield (station, sum(counts))
        except Exception, e:
            yield (('error','reducer', str(e)), 1)
        
    def combiner(self, word, counts):
        try:
            self.increment_counter('MrJob Counters','combiner',1)
            yield (word, sum(counts))
        except Exception, e:
            yield (('error','combiner', str(e)), 1)
        
if __name__ == '__main__':
    count_TMIN_TMAX.run()
# Out:
# Overwriting count_TMIN_TMAX.py

# %% [markdown]
#
#
# Running locally to test that everything works as expected:

# %%
# !python count_TMIN_TMAX.py $local_weather_data > station_TMIN_TMAX_count_head.txt
# Out:
# python: can't open file 'count_TMIN_TMAX.py': [Errno 2] No such file or directory

# %%
# !cat station_TMIN_TMAX_count_head.txt
# Out:
# "MX000008172"	30027
# "RSM00024933"	5540
# "USC00211063"	27984
# "USC00500433"	9631

# %% [markdown]
# Looks good. Lets run it on the complete data set.

# %%
# !python count_TMIN_TMAX.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > station_TMIN_TMAX_count.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-a92d71d267d0df83
# using s3://mrjob-a92d71d267d0df83/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/count_TMIN_TMAX.ubuntu.20140526.191645.067054
# creating S3 bucket 'mrjob-a92d71d267d0df83' to use as scratch space
# Copying non-input files into s3://mrjob-a92d71d267d0df83/tmp/count_TMIN_TMAX.ubuntu.20140526.191645.067054/files/
# Adding our job to existing job flow j-2KCJE554SGITB
# Job launched 30.8s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140526.191645.067054: Step 1 of 1)
# Job launched 61.7s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140526.191645.067054: Step 1 of 1)
# Job launched 92.7s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140526.191645.067054: Step 1 of 1)
# Job launched 123.5s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140526.191645.067054: Step 1 of 1)
# ...

# %%
# !head -10 station_TMIN_TMAX_count.txt
# Out:
# "AJ000037756"	2984
# "AJ000037844"	1988
# "AJ000037866"	2318
# "AJ000037899"	508
# "AJ000037907"	14366
# "AM000037627"	26
# "AM000037704"	1608
# "AQC00914873"	5162
# "AR000087270"	34603
# "AR000087344"	37464

# %% [markdown]
# We have the measurement counts for each station! Now lets merge the counts with the latitude and longitude so we can plot it on a map.

# %%
measurement_count = pd.read_csv('station_TMIN_TMAX_count.txt', sep='\t', names=['station', 'measurement_count'])
measurement_count_head = pd.read_csv('station_measurement_count_head.txt', sep='\t', names=['station', 'measurement_count'])
measurement_count.head()
# Out:
#        station  measurement_count
# 0  AJ000037756               2984
# 1  AJ000037844               1988
# 2  AJ000037866               2318
# 3  AJ000037899                508
# 4  AJ000037907              14366
#
# [5 rows x 2 columns]

# %%
merged = measurement_count.join(stations,on='station')
merged_head = measurement_count_head.join(stations,on='station')
merged.head()
# Out:
#        station  measurement_count  latitude  longitude  elevation state  \
# 0  AJ000037756               2984    40.533     48.933        755   NaN
# 1  AJ000037844               1988    40.333     48.167          4   NaN
# 2  AJ000037866               2318    40.467     50.317        -24   NaN
# 3  AJ000037899                508    39.767     46.750       1355   NaN
# 4  AJ000037907              14366    39.600     47.150        439   NaN
#
#         name GSNFLAG HCNFLAG  WMOID
# 0     MARAZA     NaN     NaN  37756
# 1   KURDAMIR     NaN     NaN  37844
# 2  PIRALLAHI     NaN     NaN  37866
# 3     SHUSHA     NaN     NaN  37899
# 4     FIZULY     NaN     NaN  37907
#
# [5 rows x 10 columns]

# %%
from mpl_toolkits.basemap import Basemap

def color_map(lon, lat, Z, figsize=(15,10), alpha=1):
    lonmin=-180
    lonmax=180
    latsmin=-80
    latsmax=80;
    
    plt.figure(figsize=figsize,dpi=300)
    m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,\
        llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
    m.drawcoastlines(color='lightgrey')
    m.drawmapboundary()
    
    x,y = m(np.array(lon), np.array(lat))
    color_map = m.scatter(x,y,c=np.array(Z),marker='.', lw=0, alpha=alpha)
    m.colorbar(color_map)

# %% [markdown]
# Plotting each station on the map and assigning color corresponding to the number of measurements a perticular station.

# %%
color_map(merged['longitude'], merged['latitude'], merged['measurement_count'])

# %% [markdown]
# Lets try to make the dots transparrent.

# %%
color_map(merged['longitude'], merged['latitude'], merged['measurement_count'], alpha=0.1)

# %% [markdown]
# ## 2) Efficient spatial data structure for geo data

# %% [markdown]
# We have around 9 million years of measurements. To fit a good model of the data, it would be smart to partition the data into smaller areas where the data might have similar patterns and fit a model on each tile. If we blindly split the world into smaller tiles, we might end up having areas with few (or no) data points and areas with many data point, leading to overfitting in some parts of the world and underfitting in other parts. We would rater partition the data into areas of equal number of measurements.
#
# We can do this by dividing the data points recursively using an R-tree ([Wikipedia](http://en.wikipedia.org/wiki/R-tree)).
#
# There are different heristics defining how to split the data. Here we will just take a simple approach and split the data recursively into two parts with alternating latitude and longitude splits.

# %%
class rtree_node:
    def __init__(self, dataframe, split_direction='longitude', lable=0, level=0, threshold=10000000, original_data=merged):
        
        # Add labels
        original_data.ix[dataframe.index,'level_%d' % level] = lable
        
        # Split
        group_1, group_2, split_at = self.find_best_split(dataframe, split_direction)
        
        # Recursion base step
        if group_1.sum(axis=0)['measurement_count'] < threshold or group_2.sum(axis=0)['measurement_count'] < threshold:
            self.is_leaf = True
            self.data = dataframe
        # Recursive step
        else:
            self.lable = lable
            self.level = level
            self.is_leaf = False
            self.split_direction = split_direction
            self.split_at = split_at
            self.children = [rtree_node(group_1, self.switch_direction(split_direction), self.lable*2, self.level+1),
                             rtree_node(group_2, self.switch_direction(split_direction), self.lable*2+1, self.level+1)]
    
    # Helper functions
   
    def print_(self, level=0):
        if self.is_leaf:
            print '    '*level, "# of measurements: ", sum([elem for elem in self.data['measurement_count']])
        else:
            self.children[0].print_(level+1)
            print '    '*level, 'split at:', self.split_at
            self.children[1].print_(level+1)

    def switch_direction(self, direction):
        latlon = ['latitude', 'longitude']
        return latlon[latlon.index(direction)-1]
        
    def find_best_split(self, dataframe, split):
        sorted_cumsum = dataframe.sort(split)['measurement_count'].cumsum()
        split_at = dataframe.sum(axis=0)['measurement_count']/2 # half of the sum
        group_1 = sorted_cumsum[sorted_cumsum <= split_at]
        group_2 = sorted_cumsum[sorted_cumsum > split_at]
        return dataframe.loc[group_1.index,:], dataframe.loc[group_2.index,:], split_at

# %%
rtree = rtree_node(merged)

# %%
rtree.print_()
# Out:
#                          # of measurements:  12962804
#                      split at: 12963115.5
#                          # of measurements:  12963427
#                  split at: 25951151.5
#                          # of measurements:  12967750
#                      split at: 12988036.0
#                          # of measurements:  13008322
#              split at: 51913129.0
#                          # of measurements:  12973977
#                      split at: 12978708.5
#                          # of measurements:  12983440
#                  split at: 25961977.5
#                          # of measurements:  12977853
#                      split at: 12983269.0
#                          # of measurements:  12988685
#          split at: 103830364.0
#                          # of measurements:  12969576
#                      split at: 12977636.5
#                          # of measurements:  12985697
#                  split at: 25957164.0
# ...

# %%
color_map(merged['longitude'], merged['latitude'], merged['level_5'])

# %%
mean(merged_head.head(), axis=0)
merged_head.head().shape
# Out:
# (5, 10)

# %% [markdown]
# Still working on it..
